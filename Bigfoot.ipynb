# %%
#https://python.plainenglish.io/where-in-the-world-is-bigfoot-7fa73d55976c

# %%
import folium
import pandas as pd

# %%
df_geo=pd.read_csv('bfro_reports_geocoded.csv')
df_geo.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# 4                  Yamhill County        Oregon  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 6496: Bicycling student has night encou...     41.45      -71.5
# 3                                                NaN       NaN        NaN
# 4                                                NaN       NaN        NaN
#
#          date   number  ... moon_phase precip_intensity  precip_probability  \
# 0         NaN  30680.0  ...        NaN              NaN                 NaN
# 1         NaN   1261.0  ...        NaN              NaN                 NaN
# 2  1974-09-20   6496.0  ...       0.16              0.0                 0.0
# 3         NaN   8000.0  ...        NaN              NaN                 NaN
# 4         NaN    703.0  ...        NaN              NaN                 NaN
#
#    precip_type  pressure                 summary  uv_index  visibility  \
# 0          NaN       NaN                     NaN       NaN         NaN
# 1          NaN       NaN                     NaN       NaN         NaN
# 2          NaN   1020.61  Foggy until afternoon.       4.0        2.75
# 3          NaN       NaN                     NaN       NaN         NaN
# 4          NaN       NaN                     NaN       NaN         NaN
#
#    wind_bearing  wind_speed
# 0           NaN         NaN
# 1           NaN         NaN
# 2         198.0        6.92
# 3           NaN         NaN
# 4           NaN         NaN
#
# [5 rows x 28 columns]

# %%
df_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5021 entries, 0 to 5020
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   observed            4983 non-null   object
#  1   location_details    4261 non-null   object
#  2   county              5021 non-null   object
#  3   state               5021 non-null   object
#  4   season              5021 non-null   object
#  5   title               4045 non-null   object
#  6   latitude            4045 non-null   float64
#  7   longitude           4045 non-null   float64
#  8   date                4045 non-null   object
#  9   number              5021 non-null   float64
#  10  classification      5021 non-null   object
#  11  geohash             4045 non-null   object
#  12  temperature_high    3338 non-null   float64
#  13  temperature_mid     3186 non-null   float64
#  14  temperature_low     3189 non-null   float64
#  15  dew_point           3373 non-null   float64
#  16  humidity            3373 non-null   float64
#  17  cloud_cover         3084 non-null   float64
#  18  moon_phase          3396 non-null   float64
#  19  precip_intensity    2712 non-null   float64
#  20  precip_probability  2710 non-null   float64
#  21  precip_type         1723 non-null   object
#  22  pressure            2619 non-null   float64
#  23  summary             3366 non-null   object
#  24  uv_index            3392 non-null   float64
#  25  visibility          3049 non-null   float64
#  26  wind_bearing        3387 non-null   float64
#  27  wind_speed          3389 non-null   float64
# dtypes: float64(17), object(11)
# memory usage: 1.1+ MB

# %%
df_geo['state'].value_counts()
# Out:
# Washington        601
# California        417
# Ohio              303
# Florida           302
# Oregon            249
# Illinois          237
# Texas             230
# Michigan          216
# Missouri          158
# Colorado          127
# Georgia           126
# Pennsylvania      115
# Kentucky          114
# New York          111
# West Virginia     103
# Arkansas          101
# Oklahoma           97
# Tennessee          96
# Idaho              96
# Alabama            94
# North Carolina     89
# Arizona            85
# Wisconsin          85
# Indiana            79
# Virginia           79
# Minnesota          72
# New Jersey         66
# Utah               58
# Iowa               56
# Montana            51
# Kansas             45
# New Mexico         42
# Louisiana          41
# South Carolina     41
# Maryland           34
# Massachusetts      29
# Wyoming            27
# Mississippi        21
# Alaska             20
# Connecticut        18
# Maine              17
# Nebraska           15
# New Hampshire      14
# South Dakota       13
# Vermont            10
# Nevada              7
# Delaware            5
# Rhode Island        5
# North Dakota        4
# Name: state, dtype: int64

# %%
df1_geo = df_geo[['observed','season','latitude','longitude']].copy()
df1_geo
# Out:
#                                                observed  season  latitude  \
# 0     I was canoeing on the Sipsey river in Alabama....  Summer       NaN
# 1     Ed L. was salmon fishing with a companion in P...    Fall       NaN
# 2     While attending U.R.I in the Fall of 1974,I wo...    Fall     41.45
# 3     Hello, My name is Doug and though I am very re...  Summer       NaN
# 4     It was May 1984. Two friends and I were up in ...  Spring       NaN
# ...                                                 ...     ...       ...
# 5016  while camping protecting other equipment befor...  Summer       NaN
# 5017  I was on my way to work on a Saturday morning ...  Spring       NaN
# 5018  On the twenty sixth and again on the twenty se...  Summer       NaN
# 5019  I was hunting on me and my neighbor's property...    Fall       NaN
# 5020  I was riding with a friend in the summer of 19...  Summer       NaN
#
#       longitude
# 0           NaN
# 1           NaN
# 2         -71.5
# 3           NaN
# 4           NaN
# ...         ...
# 5016        NaN
# 5017        NaN
# 5018        NaN
# 5019        NaN
# 5020        NaN
#
# [5021 rows x 4 columns]

# %%
df1_geo.isnull().sum()
# Out:
# observed      38
# season         0
# latitude     976
# longitude    976
# dtype: int64

# %%
df1_geo = df1_geo.dropna()

# %%
df1_geo.isnull().sum()
# Out:
# observed     0
# season       0
# latitude     0
# longitude    0
# dtype: int64

# %%
df1_geo['length']= df1_geo.loc[:,'observed'].str.len()
# Out:
# <ipython-input-16-73456aa5901c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_geo['length']= df1_geo.loc[:,'observed'].str.len()

# %%
df1_geo = df1_geo.sort_values('length', ascending=True).reset_index(drop=True)

# %%
df1_geo
# Out:
#                                                observed  season  latitude  \
# 0                                                     .  Summer  42.50817
# 1                           [see investigator comments]  Summer  42.06832
# 2                       Crossed highway in front of me.  Summer  31.85605
# 3              wood knocks,screams,yodleing,structures,  Winter  35.66440
# 4             Eyes were glowing red..........eerie.....    Fall  36.67311
# ...                                                 ...     ...       ...
# 4007  In November 1996 just a couple of days before ...    Fall  34.36778
# 4008  It happened close to midnight on August 18, 20...  Summer  46.85000
# 4009  August 1991 Stark County, East Canton OH near ...  Summer  40.75079
# 4010  My Big Foot Sightings over the years. My first...    Fall  42.43560
# 4011  Lake Milton, Ohio: Summer 1972 About the time ...  Summer  41.11740
#
#       longitude  length
# 0     -96.40213       1
# 1     -78.74920      27
# 2     -83.57655      31
# 3     -81.78065      40
# 4     -83.85683      41
# ...         ...     ...
# 4007  -94.68028   17976
# 4008 -121.25000   20517
# 4009  -81.27147   24056
# 4010 -122.23280   25332
# 4011  -80.98350   25476
#
# [4012 rows x 5 columns]

# %%
df1_geo = df1_geo.loc[df1_geo['length'] < 150]
df1_geo
# Out:
#                                              observed   season  latitude  \
# 0                                                   .   Summer  42.50817
# 1                         [see investigator comments]   Summer  42.06832
# 2                     Crossed highway in front of me.   Summer  31.85605
# 3            wood knocks,screams,yodleing,structures,   Winter  35.66440
# 4           Eyes were glowing red..........eerie.....     Fall  36.67311
# 5           I saw about 17-18 inch tracks in the mud.   Spring  47.74420
# 6          Large upright primate approx 7foot height.     Fall  37.85524
# 7          Slapping sounds, grunting sounds & chatter     Fall  35.84503
# 8   Sighted what may be a Sasquatch on White Horse...   Spring  48.21167
# 9   Tracks, 13-14 inches long, 6-7 inches wide, 5 ...  Unknown  46.55139
# 10  I saw a bigfoot and I have pictures of its foo...   Winter  36.00550
# 11  In 2019 Richfield Ohio large dark figure cross...   Spring  41.23925
# 12  Primate observed from tree stand. The animal i...     Fall  34.59583
# 13  A loud scream and an awful smell, loud crashin...     Fall  40.47326
# 14  Foot prints where found in the bad lands of No...   Winter  47.63297
# 15  (Please see Minot Daily News Vol.88 No.63 for ...   Winter  47.72964
# 16  [See investigator comments below, based on pho...     Fall  37.32355
# 17   I heard this exact sound near Trout Lake WA a...   Summer  45.94002
# 18  Large footprints and actually saw a large, fur...   Summer  37.99390
# 19  A large human-like footprint by Helmets Peak. ...     Fall  37.41250
# 20  I was driving on Markham Park Woods road at 5 ...   Winter  28.42146
# 21  I heard a series of screams/howls that are not...     Fall  35.99780
# 22  I was watching one your tv shows and the way B...   Winter  28.12565
# 23  I have a picture of some VERY convincing track...     Fall  48.40611
# 24  My family was hiking in RMNP and came across a...   Summer  40.31050
# 25  It was white. Not the typical dark color we he...   Spring  38.92993
# 26  A 7-foot upright stooped ape like figure, dark...   Winter  32.58333
# 27  I found foot prints in my yard . I made a cast...   Spring  35.56637
# 28  JUST SEEN SKUNK APE AN HOUR AGO, UNLIKELY PLAC...     Fall  29.00086
# 29  Found a fresh footprint approximately 18" or s...   Spring  47.35420
# 30  I've definitely seen one. Ran across the road....   Winter  28.29324
# 31  I was hunting for deer when I came across foot...     Fall  48.74915
# 32  I heard crashing in the woods I was walking th...   Spring  38.43260
# 33  Large footprints in sand. Something large runn...   Summer  28.72500
# 34  I seen something tall and black, about 7 feet ...   Winter  38.71682
# 35  I was crossing the railroad tracks when I saw ...   Winter  37.71917
# 36  Tracks in the snow,7 feet apart 16 inches long...   Winter  47.65885
# 37  Looked like a large chimp running along the ro...   Spring  47.29944
# 38  Driving down road 7am light fog large figure. ...   Summer  44.48875
# 39  8' + tall, upright, bipedal, dark, hair-covere...   Spring  29.53850
# 40  I was on my way home on Krome Hwy about 10:30 ...     Fall  25.73951
# 41  I heard the whooping and it was very close. Ma...   Summer  38.93027
# 42  There is a bigfoot on  **** Road in Pine Knot,...   Summer  36.40406
# 43  heard knocking on a tree after splitting firew...   Winter  46.33448
# 44  Large apelike creature moving very slowly in a...     Fall  27.44500
# 45  I found two unknown animal footprints, one I s...   Spring  47.39580
# 46  Went to get trail cams and see dark black figu...   Winter  36.83193
# 47  Heard wood knocking. Heard a boulder hitting t...     Fall  44.35978
# 48  Foot prints in the snow. I took some pictures....   Winter  41.73534
# 49  Multiple footprints, about 14 inches long and ...   Spring  47.01139
# 50  I have seen footprints of what I believe is a ...   Winter  43.66760
#
#     longitude  length
# 0   -96.40213       1
# 1   -78.74920      27
# 2   -83.57655      31
# 3   -81.78065      40
# 4   -83.85683      41
# 5  -122.89940      41
# 6   -94.11218      42
# 7  -118.63310      42
# 8  -121.67690      50
# 9  -121.46250      51
# 10  -81.08335      54
# 11  -81.62295      54
# 12  -94.55944      66
# 13  -83.44371      67
# 14 -102.72910      71
# 15 -102.70100      76
# 16  -84.26856      77
# 17 -121.75820      77
# 18  -93.87940      85
# 19 -108.12920      91
# 20  -81.23721      91
# 21  -86.20110      93
# 22  -81.02086      94
# 23 -118.98440     100
# 24 -105.81200     101
# 25  -90.53175     103
# 26  -94.15000     106
# 27  -94.98001     109
# 28  -81.64167     110
# 29 -123.23340     114
# 30  -82.35606     117
# 31 -116.84150     117
# 32  -89.79143     118
# 33  -97.06667     121
# 34  -87.68468     121
# 35  -89.48784     123
# 36  -93.75745     124
# 37 -122.18060     126
# 38  -83.88607     126
# 39  -90.59300     129
# 40  -80.48021     130
# 41  -79.68047     135
# 42  -84.23711     139
# 43 -122.05040     139
# 44  -82.39100     140
# 45 -121.53560     140
# 46  -83.42429     143
# 47 -115.85960     144
# 48  -90.22054     145
# 49 -123.66190     147
# 50  -70.62350     149

# %%
############################################################################################################################

# %%
my_map=[37,-100]
m=folium.Map(location=my_map,zoom_start=4)
for i in range(len(df1_geo)):
    latitude = df1_geo.iloc[i]["latitude"]
    longitude = df1_geo.iloc[i]["longitude"]
    popup_text = df1_geo.iloc[i]["observed"]
    icon_ = 'umbrella'
    icon_color_ = 'white'
    color_ = 'green'
    if df1_geo.iloc[i]["season"]== 'Summer':
        icon_ = 'sun­o'
        color_ = 'blue'
    elif df1_geo.iloc[i]["season"]== 'Fall':
        icon_ = 'leaf'
        color_ = 'orange'
    elif df1_geo.iloc[i]["season"]== 'Winter':
        icon_ = 'coffee'
        color_ = 'white'
        icon_color_ = 'gray'

    folium.Marker([latitude ,longitude],
                    popup = popup_text ,
                      icon=folium.Icon(prefix='fa',
                                        icon= icon_ ,
                                        color= color_,
                                        icon_color= icon_color_)).add_to(m)
m.save("my_map.html")
m
#orangefallleaf,greenspringumbrella,whitewintercoffee,bluesummersun­
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_cd4e39edf64b497c87126ef1d5b22134%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cd4e39edf64b497c87126ef1d5b22134%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cd4e39edf64b497c87126ef1d5b22134%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_cd4e39edf64b497c87126ef1d5b22134%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0%2C%20-100.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#https://python.plainenglish.io/the-continued-search-for-bigfoot-d52255db0923

# %%
bf_locations = pd.read_csv('bfro_locations.csv')
bf_locations.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129]).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_87914cb0f9ef4f768dbd00ec0b121c24%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_87914cb0f9ef4f768dbd00ec0b121c24%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_87914cb0f9ef4f768dbd00ec0b121c24%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_87914cb0f9ef4f768dbd00ec0b121c24%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129],
              icon=folium.Icon(color="red", # Outside Color
                               icon_color='white', # Icon Color/Inside Color
                               icon='info-sign' # What Kind of Icon to Use
                               )
              ).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8b9c43f6c0f5485882ba05df4e05ca65%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8b9c43f6c0f5485882ba05df4e05ca65%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8b9c43f6c0f5485882ba05df4e05ca65%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8b9c43f6c0f5485882ba05df4e05ca65%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129],
              icon=folium.Icon(color="black", # Outside Color
                               icon_color='white', # Icon Color/Inside Color
                               icon='glyphicon-check' # What Kind of Icon to Use
                               )
              ).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e998c74fa9634ff3ad51308c8001b196%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e998c74fa9634ff3ad51308c8001b196%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e998c74fa9634ff3ad51308c8001b196%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e998c74fa9634ff3ad51308c8001b196%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129],
              icon=folium.Icon(color="red", # Outside Color
                               icon_color='white', # Icon Color/Inside Color
                               icon='rebel', # What Kind of Icon to Use
                               prefix='fa' # To use Font Awesome icons
                               )
              ).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_358a48f7538049748506ce539a6877ed%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_358a48f7538049748506ce539a6877ed%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_358a48f7538049748506ce539a6877ed%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_358a48f7538049748506ce539a6877ed%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129],
              icon=folium.Icon(color="darkgreen", # Outside Color
                               icon_color='pink', # Icon Color/Inside Color
                               icon='tree', # What Kind of Icon to Use
                               prefix='fa', # To use Font Awesome icons
                               ),
              popup='The Great Pink Tree of Kansas' # Set the Pop Up text for the marker
              ).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_66fc548ca82d4bfcae327cf297d0f917%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_66fc548ca82d4bfcae327cf297d0f917%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_66fc548ca82d4bfcae327cf297d0f917%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_66fc548ca82d4bfcae327cf297d0f917%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129],
              icon=folium.Icon(color="purple", # Outside Color
                               icon_color='white', # Icon Color/Inside Color
                               icon='map-pin', # What Kind of Icon to Use
                               prefix='fa', # To use Font Awesome icons
                               ),
              popup='Center of the U.S.\nDearing, Kansas' # Set the Pop Up text for the marker
              ).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4418ce2a2eaa42cfbe9b0f472c623ec5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4418ce2a2eaa42cfbe9b0f472c623ec5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4418ce2a2eaa42cfbe9b0f472c623ec5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4418ce2a2eaa42cfbe9b0f472c623ec5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# This is our map lovingly centered on Dearing Kansas at a zoom of 15
kansas_map = folium.Map(location=[37.0902, -95.7129], zoom_start=15)
# Add the marker to the map...
folium.Marker(location=[37.0902, -95.7129],
              icon=folium.Icon(color="orange", # Outside Color
                               icon_color='black', # Icon Color/Inside Color
                               icon='lemon-o', # What Kind of Icon to Use
                               prefix='fa', # To use Font Awesome icons
                               ),
              tooltip="It's an orange lemon because folium doesn't have the color yellow...." # Set the tool tip text for the marker
              ).add_to(kansas_map)
# Display the map with the marker that's been added
kansas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4fb8e7c719de4866a456d1557cd9eb34%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4fb8e7c719de4866a456d1557cd9eb34%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4fb8e7c719de4866a456d1557cd9eb34%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4fb8e7c719de4866a456d1557cd9eb34%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# %pip install altair
# Out:
# Collecting altair
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from altair) (1.19.5)
# Requirement already satisfied: entrypoints in c:\anaconda\lib\site-packages (from altair) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\anaconda\lib\site-packages (from altair) (3.2.0)
# Requirement already satisfied: pandas>=0.18 in c:\anaconda\lib\site-packages (from altair) (1.1.3)
# Requirement already satisfied: toolz in c:\anaconda\lib\site-packages (from altair) (0.11.1)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from altair) (2.11.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\anaconda\lib\site-packages (from jsonschema>=3.0->altair) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\anaconda\lib\site-packages (from jsonschema>=3.0->altair) (1.15.0)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from jsonschema>=3.0->altair) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in c:\anaconda\lib\site-packages (from jsonschema>=3.0->altair) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\anaconda\lib\site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda\lib\site-packages (from pandas>=0.18->altair) (2020.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda\lib\site-packages (from jinja2->altair) (1.1.1)
# Installing collected packages: altair
# Successfully installed altair-4.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt

# %%
# Convert the timestamp column to datetime
bf_locations['timestamp'] = pd.to_datetime(bf_locations['timestamp'])
# Show the head of the dataframe
bf_locations.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#                   timestamp  latitude  longitude
# 0 2000-06-16 12:00:00+00:00   61.5000  -142.9000
# 1 1995-05-15 12:00:00+00:00   55.1872  -132.7982
# 2 2004-02-09 12:00:00+00:00   55.2035  -132.8202
# 3 2004-06-18 12:00:00+00:00   62.9375  -141.5667
# 4 2004-02-15 12:00:00+00:00   61.0595  -149.7853

# %%
alt.Chart(bf_locations['timestamp'].dt.year.value_counts().reset_index()).mark_bar().encode(
    x='timestamp:Q',
    y=alt.Y('index:O', sort='-x')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(bf_locations['timestamp'].dt.year.value_counts().reset_index()).mark_bar().encode(
    x='index:O',
    y='timestamp:Q'
)
# Out:
# alt.Chart(...)

# %%
bf_locations.where(bf_locations['timestamp'].dt.year == 2053).dropna(how='all')
# Out:
#        number                                              title  \
# 3277  45647.0  Report 45647: Memory told of a possible encoun...
#
#      classification                 timestamp  latitude  longitude
# 3277        Class B 2053-06-24 12:00:00+00:00  39.88078  -74.53293

# %%
print(bf_locations.where(bf_locations['timestamp'].dt.year == 2053).dropna(how='all')['title'].values)
# Out:
# ['Report 45647: Memory told of a possible encounter while camping with Girl Scouts in the Pine Barrens']

# %%
report_df = pd.read_csv('bfro_reports_geocoded.csv')
print(report_df[report_df['number'] == 45647]['observed'].values)
# Out:
# ["This was a girl scout camping trip to what is now the Brendan T. Byrne State Forest. Back then it was called the Lebanon State Forest. This is in the northern region of the New jersey Pine Barrens. We were a scout troop of about 20 girls ages 8-10 and 3 camp counselors. The camp counselors had prepared a huge pot of spaghetti and meat balls for our dinner the first night there. To get to this camp site you drove into the remote area on a one car wide sand road. The sand was very soft and cars would get stuck in the sand. Then you parked when that road ended and hiked through the forest to a lake, I believe it was called Cedar lake. We were to set up a camp site on the bank of the lake. This was in the month of June I believe so it was hot and very dry, clear night, moon shine everywhere after it got dark. Well, it wasn't long after we made a camp fire and started unpacking our gear that the counselor came around very upset, saying the the huge pot of spaghetti and meatballs was missing, no one had any idea where it was, she had placed it with other gear near the fire and it just disappeared. So, no dinner that night. She had us all come around the fire so she could keep an eye on us, do head counts. Then, it started, the thrashing of the bushes just past the campsite in the woods around us, it circled around and around, then tree knocking over and over again, then loud whistling, not a bird, something with a large lung capacity, long eerie sounds. They were, first on one side of the campsite then on the other, like they were communicating with each other. The counselors decided we were all to stay right near the fire where they could do head counts, everyone was very afraid. We were told to stay in our sleeping bags all around the fire and not move or leave our sleeping bags. Across the lake there was a boy scout troop camping at the same time. The counselors called across the lake, not a big lake, for them to come across and help us. The boy scouts and counselors did and sat with us at the fire and listened to the continuing knocking sounds and whistling and thrashing. It was not a prank. The boys scouts were afraid just like we were and decided we weren't to leave until daybreak because it would be too dangerous to hike back through the woods to the cars. There were no cell phones back then so everyone had to wait until we could run through the woods to the cars and get to a phone to report this. The boy scout counselor did that and the State Police were arriving as we drove away and out of the park at about 5:30am. My mother told me first that I was never going camping again, and second that the police told the girl scout counselor that they found nothing anywhere around the campsites or in the woods, the spaghetti was never found. Back then, you would attribute such things happening to the jersey devil, but in this case I would have to say after all the information today, that it was a bigfoot or a couple bigfoots who just did not want us there. It also made no sense to think that it was a human or humans who wanted us out of there, If a human had stolen the food, he would have gone far away so not to be caught, certainly not scare us so bad all night long so that we would call the police."]

# %%
bf_locations = bf_locations.where(bf_locations['timestamp'].dt.year == 2004).dropna(how='all')
bf_locations
# Out:
#        number                                              title  \
# 2      7963.0  Report 7963: Sasquatch walks past window of ho...
# 3      9317.0  Report 9317: Driver on Alcan Highway has noon,...
# 4     13038.0  Report 13038: Snowmobiler has encounter in dee...
# 24     7235.0  Report 7235: Recollection of an afternoon sigh...
# 26     8171.0     Report 8171: Nighttime Sighting on County Road
# ...       ...                                                ...
# 4146  14987.0  Report 14987: Family in a camper describes sta...
# 4192   7727.0  Report 7727: Mother and daughter find footprin...
# 4195  11828.0  Report 11828: Woman experiences rock throwing,...
# 4202  14739.0  Report 14739: Possible vocalization and stalki...
# 4235  25381.0  Report 25381: Large bipedal figure seen leapin...
#
#      classification                 timestamp  latitude  longitude
# 2           Class A 2004-02-09 12:00:00+00:00  55.20350 -132.82020
# 3           Class A 2004-06-18 12:00:00+00:00  62.93750 -141.56670
# 4           Class A 2004-02-15 12:00:00+00:00  61.05950 -149.78530
# 24          Class A 2004-05-28 12:00:00+00:00  34.73250  -86.52105
# 26          Class A 2004-05-09 12:00:00+00:00  33.36740  -86.64066
# ...             ...                       ...       ...        ...
# 4146        Class B 2004-04-15 12:00:00+00:00  44.47230  -90.71670
# 4192        Class B 2004-01-01 12:00:00+00:00  38.69340  -79.56530
# 4195        Class B 2004-06-05 12:00:00+00:00  39.61958  -81.14833
# 4202        Class B 2004-10-30 12:00:00+00:00  38.20065  -80.17294
# 4235        Class C 2004-09-15 12:00:00+00:00  28.21492  -82.45240
#
# [252 rows x 6 columns]

# %%
bf_locations['timestamp'] = bf_locations['timestamp'].dt.strftime('%Y-%m-%d')
bf_locations
# Out:
#        number                                              title  \
# 2      7963.0  Report 7963: Sasquatch walks past window of ho...
# 3      9317.0  Report 9317: Driver on Alcan Highway has noon,...
# 4     13038.0  Report 13038: Snowmobiler has encounter in dee...
# 24     7235.0  Report 7235: Recollection of an afternoon sigh...
# 26     8171.0     Report 8171: Nighttime Sighting on County Road
# ...       ...                                                ...
# 4146  14987.0  Report 14987: Family in a camper describes sta...
# 4192   7727.0  Report 7727: Mother and daughter find footprin...
# 4195  11828.0  Report 11828: Woman experiences rock throwing,...
# 4202  14739.0  Report 14739: Possible vocalization and stalki...
# 4235  25381.0  Report 25381: Large bipedal figure seen leapin...
#
#      classification   timestamp  latitude  longitude
# 2           Class A  2004-02-09  55.20350 -132.82020
# 3           Class A  2004-06-18  62.93750 -141.56670
# 4           Class A  2004-02-15  61.05950 -149.78530
# 24          Class A  2004-05-28  34.73250  -86.52105
# 26          Class A  2004-05-09  33.36740  -86.64066
# ...             ...         ...       ...        ...
# 4146        Class B  2004-04-15  44.47230  -90.71670
# 4192        Class B  2004-01-01  38.69340  -79.56530
# 4195        Class B  2004-06-05  39.61958  -81.14833
# 4202        Class B  2004-10-30  38.20065  -80.17294
# 4235        Class C  2004-09-15  28.21492  -82.45240
#
# [252 rows x 6 columns]

# %%
bf_locations = bf_locations.merge(report_df[['number', 'season']], on='number')
bf_locations
# Out:
#       number                                              title  \
# 0     7963.0  Report 7963: Sasquatch walks past window of ho...
# 1     9317.0  Report 9317: Driver on Alcan Highway has noon,...
# 2    13038.0  Report 13038: Snowmobiler has encounter in dee...
# 3     7235.0  Report 7235: Recollection of an afternoon sigh...
# 4     8171.0     Report 8171: Nighttime Sighting on County Road
# ..       ...                                                ...
# 236  11026.0  Report 11026: Possible vocalizations heard by ...
# 237  14987.0  Report 14987: Family in a camper describes sta...
# 238   7727.0  Report 7727: Mother and daughter find footprin...
# 239  11828.0  Report 11828: Woman experiences rock throwing,...
# 240  14739.0  Report 14739: Possible vocalization and stalki...
#
#     classification   timestamp  latitude  longitude  season
# 0          Class A  2004-02-09  55.20350 -132.82020  Winter
# 1          Class A  2004-06-18  62.93750 -141.56670  Summer
# 2          Class A  2004-02-15  61.05950 -149.78530  Winter
# 3          Class A  2004-05-28  34.73250  -86.52105  Summer
# 4          Class A  2004-05-09  33.36740  -86.64066  Winter
# ..             ...         ...       ...        ...     ...
# 236        Class B  2004-11-16  46.64250  -91.17130    Fall
# 237        Class B  2004-04-15  44.47230  -90.71670  Spring
# 238        Class B  2004-01-01  38.69340  -79.56530  Winter
# 239        Class B  2004-06-05  39.61958  -81.14833  Summer
# 240        Class B  2004-10-30  38.20065  -80.17294    Fall
#
# [241 rows x 7 columns]

# %%
bf_locations['season'].unique()
# Out:
# array(['Winter', 'Summer', 'Fall', 'Spring', 'Unknown'], dtype=object)

# %%
color_dict = {'Winter': 'blue',
              'Summer': 'red',
              'Spring': 'green',
              'Fall': 'orange',
              'Unknown': 'black'
              }
records = bf_locations[['latitude', 'longitude', 'season', 'title', 'timestamp']].to_records()
records[0]
# Out:
# (0, 55.2035, -132.8202, 'Winter', 'Report 7963: Sasquatch walks past window of house at night', '2004-02-09')

# %%
for record in records[:2]:
    print(f"Lat: {record[1]}")
    print(f"Long: {record[2]}")
    print(f"Season Color: {record[3]} is mapped to {color_dict[record[3]]}")
    print(f"Title: {record[4]}")
    print(f"Timestamp: {record[5]}")
# Out:
# Lat: 55.2035
# Long: -132.8202
# Season Color: Winter is mapped to blue
# Title: Report 7963: Sasquatch walks past window of house at night
# Timestamp: 2004-02-09
# Lat: 62.9375
# Long: -141.5667
# Season Color: Summer is mapped to red
# Title: Report 9317: Driver on Alcan Highway has noon, road encounter near Alaska-Canada border
# Timestamp: 2004-06-18

# %%
color_dict = {'Winter': 'blue',
              'Summer': 'red',
              'Spring': 'green',
              'Fall': 'orange',
              'Unknown': 'black'
              }
records = bf_locations[['latitude', 'longitude', 'season', 'title', 'timestamp']].to_records()

# This is our map lovingly centered on Dearing Kansas at a zoom of 15
bf_map = folium.Map(location=[37.0902, -95.7129], zoom_start=5)
# Add the markers to the map...
for record in records:
    folium.Marker(location=[record[1], record[2]],
                  icon=folium.Icon(color=color_dict[record[3]], # Outside Color to Season Color
                                   icon_color='white', # Icon Color/Inside Color
                                   icon='search', # What Kind of Icon to Use
                                   prefix='fa', # To use Font Awesome icons
                                   ),
                  popup=record[4], # Set pop up to the title of the sighting
                  tooltip=record[5] # Set the tool tip to year of each sighting
                  ).add_to(bf_map)
# Display the map with the marker that's been added
bf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3ae0694ca15a4fb2933d0fdd37e30b16%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3ae0694ca15a4fb2933d0fdd37e30b16%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3ae0694ca15a4fb2933d0fdd37e30b16%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3ae0694ca15a4fb2933d0fdd37e30b16%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.0902%2C%20-95.7129%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
